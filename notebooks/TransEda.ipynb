# %%
arrow::read_parquet(here("data", "atpTrans.parquet")) -> atp
atp
# Out:
#        winner.name                winner.id winner.bornAt  winner.domHand
# 1      Patrick Rafter             r255      Australia      Right-Handed
# 2      Dennis Van Scheppingen     s559      Netherlands    Right-Handed
# 3      Jan Siemerink              s381      Netherlands    Left-Handed
# 4      Martin Damm                d214      Czech Republic Right-Handed
# 5      Patrick Rafter             r255      Australia      Right-Handed
# 6      Dennis Van Scheppingen     s559      Netherlands    Right-Handed
# 7      Jan Siemerink              s381      Netherlands    Left-Handed
# 8      Karol Kucera               k237      Czech Republic Right-Handed
# 9      Martin Damm                d214      Czech Republic Right-Handed
# 10     Patrick Rafter             r255      Australia      Right-Handed
# 11     Richard Krajicek           k214      Netherlands    Right-Handed
# 12     Sjeng Schalken             s572      Netherlands    Right-Handed
# ...

# %%
atp %>% summary()
# Out:
#  winner.name         winner.id         winner.bornAt      winner.domHand
#  Length:682069      Length:682069      Length:682069      Length:682069
#  Class :character   Class :character   Class :character   Class :character
#  Mode  :character   Mode  :character   Mode  :character   Mode  :character
#
#
#
#
#  winner.backHand    winner.height    looser.name         looser.id
#  Length:682069      Min.   :  0.0    Length:682069      Length:682069
#  Class :character   1st Qu.:180.0    Class :character   Class :character
#  Mode  :character   Median :185.0    Mode  :character   Mode  :character
#                     Mean   :181.7
#                     3rd Qu.:188.0
#                     Max.   :510.0
#                     NA's   :163431
#  looser.bornAt      looser.domHand     looser.backHand    looser.height
#  Length:682069      Length:682069      Length:682069      Min.   :  0.0
#  Class :character   Class :character   Class :character   1st Qu.:180.0
# ...

# %%
atp %>% filter(tournament.duration < 0)
# Out:
# Error in eval(expr, envir, enclos): object 'atp' not found
# Traceback:
#
# 1. atp %>% filter(tournament.duration < 0)
# 2. filter(., tournament.duration < 0)
